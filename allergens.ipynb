# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv('/ML/datasets/allergies_10k.csv')

# %%
allergens = df[df['allergens'] != '[]']

# %%
display(allergens[['allergens', 'ingredient']])
# Out:
#                                                                      allergens  \
# 3                                                                ['tree nuts']
# 4                                                                    ['dairy']
# 7                                                                    ['dairy']
# 14                                                                  ['celery']
# 18                                               ['eggs', 'dairy', 'soybeans']
# 19                                                                   ['dairy']
# 20                                                                   ['dairy']
# 25                                                       ['wheat', 'soybeans']
# 33                                                               ['tree nuts']
# 35                                           ['wheat', 'soybeans', '**gluten']
# 38                                                                ['soybeans']
# ...
